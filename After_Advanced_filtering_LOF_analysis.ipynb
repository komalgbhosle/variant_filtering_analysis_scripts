# %%
import pandas as pd 
import csv
import os

# %%
df = pd.read_csv('Asthma_final_filtered_mutations.csv')
# Out:
# /data/home/komal.bhosle/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head
# Out:
# <bound method NDFrame.head of          Unnamed: 0                    CHROM      POS ID REF ALT    QUAL  \
# 0                 0                     chr1    14522  .   G   A  118.64
# 1                 0                     chr1    14522  .   G   A  118.64
# 2                 0                     chr1    14522  .   G   A  118.64
# 3                 0                     chr1    14522  .   G   A  118.64
# 4                 0                     chr1    14522  .   G   A  118.64
# 5                 1                     chr1    14590  .   G   A   45.64
# 6                 1                     chr1    14590  .   G   A   45.64
# 7                 1                     chr1    14590  .   G   A   45.64
# 8                 1                     chr1    14590  .   G   A   45.64
# 9                 2                     chr1    14673  .   G   C   71.32
# 10                2                     chr1    14673  .   G   C   71.32
# 11                2                     chr1    14673  .   G   C   71.32
# 12                2                     chr1    14673  .   G   C   71.32
# 13                3                     chr1    15015  .   G   C  259.65
# 14                3                     chr1    15015  .   G   C  259.65
# 15                3                     chr1    15015  .   G   C  259.65
# 16                3                     chr1    15015  .   G   C  259.65
# 17                4                     chr1    17385  .   G   A   57.64
# 18                4                     chr1    17385  .   G   A   57.64
# 19                4                     chr1    17385  .   G   A   57.64
# 20                4                     chr1    17385  .   G   A   57.64
# 21                5                     chr1    17452  .   C   T   84.64
# 22                5                     chr1    17452  .   C   T   84.64
# 23                5                     chr1    17452  .   C   T   84.64
# 24                5                     chr1    17452  .   C   T   84.64
# 25                6                     chr1    17538  .   C   A  132.64
# 26                6                     chr1    17538  .   C   A  132.64
# 27                6                     chr1    17538  .   C   A  132.64
# 28                6                     chr1    17538  .   C   A  132.64
# 29                7                     chr1    17594  .   C   T   37.64
# ...             ...                      ...      ... ..  ..  ..     ...
# 6855639     1125686         chrUn_KI270330v1     1457  .   G   A  109.64
# 6855640     1125686         chrUn_KI270330v1     1457  .   G   A  109.64
# 6855641     1125686         chrUn_KI270330v1     1457  .   G   A  109.64
# 6855642     1125687         chrUn_KI270330v1     1458  .   T   C  109.64
# 6855643     1125687         chrUn_KI270330v1     1458  .   T   C  109.64
# 6855644     1125687         chrUn_KI270330v1     1458  .   T   C  109.64
# 6855645     1125688         chrUn_GL000216v2   161956  .   C   T   78.32
# 6855646     1125689         chrUn_GL000216v2   161962  .   C   A   78.32
# 6855647     1125690         chrUn_GL000216v2   161967  .   C   T   78.32
# 6855648     1125691         chrUn_GL000216v2   169639  .   G   T   35.48
# 6855649     1125692      chr8_KI270819v1_alt    86029  .   C   T   66.32
# 6855650     1125693      chr8_KI270819v1_alt    90475  .   G   A   31.64
# 6855651     1125694     chr14_KI270847v1_alt  1497716  .   G   T   35.48
# 6855652     1125695     chr14_KI270847v1_alt  1497717  .   G   T   35.48
# 6855653     1125696     chr14_KI270847v1_alt  1497719  .   G   A   35.48
# 6855654     1125697     chr17_KI270858v1_alt   117873  .   T   C   78.32
# 6855655     1125698     chr17_KI270858v1_alt   117889  .   C   A   78.32
# 6855656     1125699     chr19_GL383575v2_alt     8234  .   T   C   76.84
# 6855657     1125700     chr22_KI270875v1_alt     2816  .   G   A   74.32
# 6855658     1125701     chr22_KI270875v1_alt     2837  .   T   C   78.32
# 6855659     1125702     chr22_KI270875v1_alt     2839  .   C   T   78.32
# 6855660     1125703     chr22_KI270875v1_alt     2840  .   C   T   78.32
# 6855661     1125704     chr22_KI270875v1_alt    29365  .   G   A  142.64
# 6855662     1125705     chr22_KI270875v1_alt    29441  .   A   C   93.64
# 6855663     1125706     chr22_KI270875v1_alt    40061  .   A   G   37.32
# 6855664     1125707      chr7_KI270899v1_alt    13793  .   A   G   35.48
# 6855665     1125708      chr7_KI270899v1_alt    13797  .   A   T   35.48
# 6855666     1125709      chr6_KI270802v1_alt    71744  .   T   G   65.32
# 6855667     1125710      chr7_GL383534v2_alt    75942  .   A   G   73.32
# 6855668     1125711  chr22_KI270732v1_random    36439  .   T   C   56.32
#
#         FILTER          FORMAT  Sample_Count  ...       Feature_type  \
# 0         PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 1         PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 2         PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 3         PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 4         PASS  GT:AD:DP:GQ:PL             2  ...  RegulatoryFeature
# 5         PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 6         PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 7         PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 8         PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 9         PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 10        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 11        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 12        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 13        PASS  GT:AD:DP:GQ:PL             4  ...         Transcript
# 14        PASS  GT:AD:DP:GQ:PL             4  ...         Transcript
# 15        PASS  GT:AD:DP:GQ:PL             4  ...         Transcript
# 16        PASS  GT:AD:DP:GQ:PL             4  ...         Transcript
# 17        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 18        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 19        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 20        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 21        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 22        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 23        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 24        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# 25        PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 26        PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 27        PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 28        PASS  GT:AD:DP:GQ:PL             2  ...         Transcript
# 29        PASS  GT:AD:DP:GQ:PL             1  ...         Transcript
# ...        ...             ...           ...  ...                ...
# 6855639   PASS  GT:AD:DP:GQ:PL             1  ...  RegulatoryFeature
# 6855640   PASS  GT:AD:DP:GQ:PL             1  ...  RegulatoryFeature
# 6855641   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855642   PASS  GT:AD:DP:GQ:PL             1  ...  RegulatoryFeature
# 6855643   PASS  GT:AD:DP:GQ:PL             1  ...  RegulatoryFeature
# 6855644   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855645   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855646   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855647   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855648   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855649   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855650   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855651   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855652   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855653   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855654   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855655   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855656   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855657   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855658   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855659   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855660   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855661   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855662   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855663   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855664   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855665   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855666   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855667   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
# 6855668   PASS  GT:AD:DP:GQ:PL             1  ...                NaN
#
#                  Feature                             BIOTYPE   EXON INTRON  \
# 0        ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# 1        ENST00000456328                processed_transcript    NaN    NaN
# 2        ENST00000488147              unprocessed_pseudogene    NaN  10/10
# 3        ENST00000619216                               miRNA    NaN    NaN
# 4        ENSR00000000002               open_chromatin_region    NaN    NaN
# 5        ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# 6        ENST00000456328                processed_transcript    NaN    NaN
# 7        ENST00000488147              unprocessed_pseudogene    NaN  10/10
# 8        ENST00000619216                               miRNA    NaN    NaN
# 9        ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# 10       ENST00000456328                processed_transcript    NaN    NaN
# 11       ENST00000488147              unprocessed_pseudogene    NaN  10/10
# 12       ENST00000619216                               miRNA    NaN    NaN
# 13       ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# 14       ENST00000456328                processed_transcript    NaN    NaN
# 15       ENST00000488147              unprocessed_pseudogene  10/11    NaN
# 16       ENST00000619216                               miRNA    NaN    NaN
# 17       ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# 18       ENST00000456328                processed_transcript    NaN    NaN
# 19       ENST00000488147              unprocessed_pseudogene    NaN   5/10
# 20       ENST00000619216                               miRNA    1/1    NaN
# 21       ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# 22       ENST00000456328                processed_transcript    NaN    NaN
# 23       ENST00000488147              unprocessed_pseudogene    NaN   5/10
# 24       ENST00000619216                               miRNA    NaN    NaN
# 25       ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# 26       ENST00000456328                processed_transcript    NaN    NaN
# 27       ENST00000488147              unprocessed_pseudogene    NaN   5/10
# 28       ENST00000619216                               miRNA    NaN    NaN
# 29       ENST00000450305  transcribed_unprocessed_pseudogene    NaN    NaN
# ...                  ...                                 ...    ...    ...
# 6855639  ENSR00000338588                   CTCF_binding_site    NaN    NaN
# 6855640  ENSR00000338589                     TF_binding_site    NaN    NaN
# 6855641              NaN                                 NaN    NaN    NaN
# 6855642  ENSR00000338588                   CTCF_binding_site    NaN    NaN
# 6855643  ENSR00000338589                     TF_binding_site    NaN    NaN
# 6855644              NaN                                 NaN    NaN    NaN
# 6855645              NaN                                 NaN    NaN    NaN
# 6855646              NaN                                 NaN    NaN    NaN
# 6855647              NaN                                 NaN    NaN    NaN
# 6855648              NaN                                 NaN    NaN    NaN
# 6855649              NaN                                 NaN    NaN    NaN
# 6855650              NaN                                 NaN    NaN    NaN
# 6855651              NaN                                 NaN    NaN    NaN
# 6855652              NaN                                 NaN    NaN    NaN
# 6855653              NaN                                 NaN    NaN    NaN
# 6855654              NaN                                 NaN    NaN    NaN
# 6855655              NaN                                 NaN    NaN    NaN
# 6855656              NaN                                 NaN    NaN    NaN
# 6855657              NaN                                 NaN    NaN    NaN
# 6855658              NaN                                 NaN    NaN    NaN
# 6855659              NaN                                 NaN    NaN    NaN
# 6855660              NaN                                 NaN    NaN    NaN
# 6855661              NaN                                 NaN    NaN    NaN
# 6855662              NaN                                 NaN    NaN    NaN
# 6855663              NaN                                 NaN    NaN    NaN
# 6855664              NaN                                 NaN    NaN    NaN
# 6855665              NaN                                 NaN    NaN    NaN
# 6855666              NaN                                 NaN    NaN    NaN
# 6855667              NaN                                 NaN    NaN    NaN
# 6855668              NaN                                 NaN    NaN    NaN
#
#         Existing_variation SIFT PolyPhen  AF ExAC_AF
# 0                      NaN  NaN      NaN NaN     NaN
# 1                      NaN  NaN      NaN NaN     NaN
# 2                      NaN  NaN      NaN NaN     NaN
# 3                      NaN  NaN      NaN NaN     NaN
# 4                      NaN  NaN      NaN NaN     NaN
# 5                 rs707679  NaN      NaN NaN     NaN
# 6                 rs707679  NaN      NaN NaN     NaN
# 7                 rs707679  NaN      NaN NaN     NaN
# 8                 rs707679  NaN      NaN NaN     NaN
# 9                   rs4690  NaN      NaN NaN     NaN
# 10                  rs4690  NaN      NaN NaN     NaN
# 11                  rs4690  NaN      NaN NaN     NaN
# 12                  rs4690  NaN      NaN NaN     NaN
# 13                     NaN  NaN      NaN NaN     NaN
# 14                     NaN  NaN      NaN NaN     NaN
# 15                     NaN  NaN      NaN NaN     NaN
# 16                     NaN  NaN      NaN NaN     NaN
# 17             rs201535981  NaN      NaN NaN   0.122
# 18             rs201535981  NaN      NaN NaN   0.122
# 19             rs201535981  NaN      NaN NaN   0.122
# 20             rs201535981  NaN      NaN NaN   0.122
# 21             rs200503540  NaN      NaN NaN   0.016
# 22             rs200503540  NaN      NaN NaN   0.016
# 23             rs200503540  NaN      NaN NaN   0.016
# 24             rs200503540  NaN      NaN NaN   0.016
# 25              rs71260068  NaN      NaN NaN     NaN
# 26              rs71260068  NaN      NaN NaN     NaN
# 27              rs71260068  NaN      NaN NaN     NaN
# 28              rs71260068  NaN      NaN NaN     NaN
# 29             rs377698370  NaN      NaN NaN     NaN
# ...                    ...  ...      ...  ..     ...
# 6855639                NaN  NaN      NaN NaN     NaN
# 6855640                NaN  NaN      NaN NaN     NaN
# 6855641                NaN  NaN      NaN NaN     NaN
# 6855642                NaN  NaN      NaN NaN     NaN
# 6855643                NaN  NaN      NaN NaN     NaN
# 6855644                NaN  NaN      NaN NaN     NaN
# 6855645                NaN  NaN      NaN NaN     NaN
# 6855646                NaN  NaN      NaN NaN     NaN
# 6855647                NaN  NaN      NaN NaN     NaN
# 6855648                NaN  NaN      NaN NaN     NaN
# 6855649                NaN  NaN      NaN NaN     NaN
# 6855650                NaN  NaN      NaN NaN     NaN
# 6855651                NaN  NaN      NaN NaN     NaN
# 6855652                NaN  NaN      NaN NaN     NaN
# 6855653                NaN  NaN      NaN NaN     NaN
# 6855654                NaN  NaN      NaN NaN     NaN
# 6855655                NaN  NaN      NaN NaN     NaN
# 6855656                NaN  NaN      NaN NaN     NaN
# 6855657                NaN  NaN      NaN NaN     NaN
# 6855658                NaN  NaN      NaN NaN     NaN
# 6855659                NaN  NaN      NaN NaN     NaN
# 6855660                NaN  NaN      NaN NaN     NaN
# 6855661                NaN  NaN      NaN NaN     NaN
# 6855662                NaN  NaN      NaN NaN     NaN
# 6855663                NaN  NaN      NaN NaN     NaN
# 6855664                NaN  NaN      NaN NaN     NaN
# 6855665                NaN  NaN      NaN NaN     NaN
# 6855666                NaN  NaN      NaN NaN     NaN
# 6855667                NaN  NaN      NaN NaN     NaN
# 6855668                NaN  NaN      NaN NaN     NaN
#
# [6855669 rows x 23 columns]>

# %%
removed_columns = df.drop(['Unnamed: 0'],axis=1)

# %%
removed_columns.head()
# Out:
#   CHROM    POS ID REF ALT    QUAL FILTER          FORMAT  Sample_Count  \
# 0  chr1  14522  .   G   A  118.64   PASS  GT:AD:DP:GQ:PL             2
# 1  chr1  14522  .   G   A  118.64   PASS  GT:AD:DP:GQ:PL             2
# 2  chr1  14522  .   G   A  118.64   PASS  GT:AD:DP:GQ:PL             2
# 3  chr1  14522  .   G   A  118.64   PASS  GT:AD:DP:GQ:PL             2
# 4  chr1  14522  .   G   A  118.64   PASS  GT:AD:DP:GQ:PL             2
#
#                                     Consequence  ...       Feature_type  \
# 0                       downstream_gene_variant  ...         Transcript
# 1                       downstream_gene_variant  ...         Transcript
# 2  intron_variant&non_coding_transcript_variant  ...         Transcript
# 3                       downstream_gene_variant  ...         Transcript
# 4                     regulatory_region_variant  ...  RegulatoryFeature
#
#            Feature                             BIOTYPE EXON INTRON  \
# 0  ENST00000450305  transcribed_unprocessed_pseudogene  NaN    NaN
# 1  ENST00000456328                processed_transcript  NaN    NaN
# 2  ENST00000488147              unprocessed_pseudogene  NaN  10/10
# 3  ENST00000619216                               miRNA  NaN    NaN
# 4  ENSR00000000002               open_chromatin_region  NaN    NaN
#
#   Existing_variation SIFT PolyPhen  AF ExAC_AF
# 0                NaN  NaN      NaN NaN     NaN
# 1                NaN  NaN      NaN NaN     NaN
# 2                NaN  NaN      NaN NaN     NaN
# 3                NaN  NaN      NaN NaN     NaN
# 4                NaN  NaN      NaN NaN     NaN
#
# [5 rows x 22 columns]

# %%
missense_variants = removed_columns[removed_columns['Consequence'].str.contains('missense_variant', na=False)]

# %%
missense_variants.head()
# Out:
#      CHROM     POS ID REF ALT   QUAL FILTER          FORMAT  Sample_Count  \
# 1998  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 1999  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 2001  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 2010  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 2011  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
#
#            Consequence  ... Feature_type          Feature         BIOTYPE  \
# 1998  missense_variant  ...   Transcript  ENST00000341065  protein_coding
# 1999  missense_variant  ...   Transcript  ENST00000342066  protein_coding
# 2001  missense_variant  ...   Transcript  ENST00000455979  protein_coding
# 2010  missense_variant  ...   Transcript  ENST00000616125  protein_coding
# 2011  missense_variant  ...   Transcript  ENST00000617307  protein_coding
#
#        EXON INTRON Existing_variation            SIFT  \
# 1998  12/12    NaN                NaN  deleterious(0)
# 1999  14/14    NaN                NaN  deleterious(0)
# 2001    7/7    NaN                NaN  deleterious(0)
# 2010  12/12    NaN                NaN  deleterious(0)
# 2011  13/13    NaN                NaN  deleterious(0)
#
#                       PolyPhen  AF ExAC_AF
# 1998  possibly_damaging(0.759) NaN     NaN
# 1999  possibly_damaging(0.876) NaN     NaN
# 2001  probably_damaging(0.999) NaN     NaN
# 2010  probably_damaging(0.987) NaN     NaN
# 2011  probably_damaging(0.959) NaN     NaN
#
# [5 rows x 22 columns]

# %%
#to count no of missense variants
len(missense_variants.axes[0])
# Out:
# 114467

# %%
#To filter LOF mutations: missense varinats having "deleterious" effect in SIFT and "damaging" effect in polyphen database
LOF_mutations = removed_columns[removed_columns['Consequence'].str.contains("missense_variant") & removed_columns['SIFT'].str.contains("deleterious") & removed_columns['PolyPhen'].str.contains("damaging")]

# %%
LOF_mutations.head()
# Out:
#      CHROM     POS ID REF ALT   QUAL FILTER          FORMAT  Sample_Count  \
# 1998  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 1999  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 2001  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 2010  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
# 2011  chr1  943923  .   G   A  70.64   PASS  GT:AD:DP:GQ:PL             1
#
#            Consequence  ... Feature_type          Feature         BIOTYPE  \
# 1998  missense_variant  ...   Transcript  ENST00000341065  protein_coding
# 1999  missense_variant  ...   Transcript  ENST00000342066  protein_coding
# 2001  missense_variant  ...   Transcript  ENST00000455979  protein_coding
# 2010  missense_variant  ...   Transcript  ENST00000616125  protein_coding
# 2011  missense_variant  ...   Transcript  ENST00000617307  protein_coding
#
#        EXON INTRON Existing_variation            SIFT  \
# 1998  12/12    NaN                NaN  deleterious(0)
# 1999  14/14    NaN                NaN  deleterious(0)
# 2001    7/7    NaN                NaN  deleterious(0)
# 2010  12/12    NaN                NaN  deleterious(0)
# 2011  13/13    NaN                NaN  deleterious(0)
#
#                       PolyPhen  AF ExAC_AF
# 1998  possibly_damaging(0.759) NaN     NaN
# 1999  possibly_damaging(0.876) NaN     NaN
# 2001  probably_damaging(0.999) NaN     NaN
# 2010  probably_damaging(0.987) NaN     NaN
# 2011  probably_damaging(0.959) NaN     NaN
#
# [5 rows x 22 columns]

# %%
#To count no of LOF mutations
len(LOF_mutations.axes[0])
# Out:
# 41691

# %%
#print output
LOF_mutations.to_csv('Asthma_LOF_mutations.csv')
