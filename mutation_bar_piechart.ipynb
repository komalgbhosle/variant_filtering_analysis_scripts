# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
input = pd.read_csv('Asthma_final_mutations.csv')
# Out:
# /data/home/komal.bhosle/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (15,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
input.head()
# Out:
#    Unnamed: 0 CHROM     POS ID REF ALT    QUAL FILTER          FORMAT  \
# 0           0  chr1  135163  .   C   T  105.84   PASS  GT:AD:DP:GQ:PL
# 1           0  chr1  135163  .   C   T  105.84   PASS  GT:AD:DP:GQ:PL
# 2           0  chr1  135163  .   C   T  105.84   PASS  GT:AD:DP:GQ:PL
# 3           0  chr1  135163  .   C   T  105.84   PASS  GT:AD:DP:GQ:PL
# 4           0  chr1  135163  .   C   T  105.84   PASS  GT:AD:DP:GQ:PL
#
#                           Consequence  ...   SRR7721278   SRR7721279  \
# 0             downstream_gene_variant  ...  ./.:.:.:.:.  ./.:.:.:.:.
# 1               upstream_gene_variant  ...  ./.:.:.:.:.  ./.:.:.:.:.
# 2             downstream_gene_variant  ...  ./.:.:.:.:.  ./.:.:.:.:.
# 3  non_coding_transcript_exon_variant  ...  ./.:.:.:.:.  ./.:.:.:.:.
# 4             downstream_gene_variant  ...  ./.:.:.:.:.  ./.:.:.:.:.
#
#              SRR7721280           SRR7721281   SRR7721282   SRR7721283  \
# ...

# %%
len(input.axes[0])
# Out:
# 12808078

# %%
unique_mutations = input.drop_duplicates()

# %%
len(unique_mutations.axes[0])
# Out:
# 986823

# %%
#df = input.groupby('Consequence')['','POS','REF','ALT'].nunique()

# %%
df2 = unique_mutations.drop_duplicates().Consequence.value_counts()

# %%
df2.head()
# Out:
# downstream_gene_variant                         245544
# intron_variant                                  238058
# upstream_gene_variant                           149095
# intron_variant&non_coding_transcript_variant    102917
# intron_variant&NMD_transcript_variant            47526
# Name: Consequence, dtype: int64

# %%
df3 = df2.reset_index()

# %%
#df3 = df2[["Mutation_type","count"]]

# %%
#df3 = df2.to_frame()

# %%
df3.head()
# Out:
#                                           index  Consequence
# 0                       downstream_gene_variant       245544
# 1                                intron_variant       238058
# 2                         upstream_gene_variant       149095
# 3  intron_variant&non_coding_transcript_variant       102917
# 4         intron_variant&NMD_transcript_variant        47526

# %%
df_index = df2['index']

# %%
float(df_index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-134-76786c9d6f3f> in <module>
# ----> 1 float(df_index)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#      91             return converter(self.iloc[0])
#      92         raise TypeError("cannot convert the series to "
# ---> 93                         "{0}".format(str(converter)))
#      94
#      95     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'float'>

# %%
df2_index = df2['Consequence']

# %%
out = df2.plot(kind="barh", stacked=True, colormap='Paired', figsize=(7,9))
plt.xticks(rotation=30, horizontalalignment="center")
plt.title("Bar plot")
plt.xlabel("Mutation_type")
plt.ylabel("No of mutation")
plt.show()

# %%
df2.plot(kind='pie', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f290a49e0b8>],
#       dtype=object)

# %%
plot = df3.plot.pie(y='Consequence',figsize=(5, 5))
